# %% [markdown]
# ## Dosya Yükleme

# %% [markdown]
# **1-"Car_sales.csv" dosyasını pandas frame olarak yükleyin ve lk 5 satırını ekranda gösterin?**

# %%
import pandas as pd

# %% [markdown]
# #dosya=...

# %%
dosya="Car_sales.csv"

# %% [markdown]
# #veri=pd.read_

# %%
veri=pd.read_csv(dosya)
veri.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %% [markdown]
# **2-Dosyayı binary bir şekilde kaydedin ve kaydettiğiniz dosyayı okuyun**

# %%
veri2=pd.read_csv(dosya)
veri2.to_pickle("pickle")
df=pd.read_pickle("pickle")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %% [markdown]
# ## EKSİK VERİ İŞLEME

# %% [markdown]
# **3-Tüm tablolarda boş veri olup olmadığını kontrol edin?**

# %%
veri.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %% [markdown]
# **4-Manufacturer sütununda bulunan eksik bilgileri görüntüleyin**

# %%
veri["Manufacturer"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **5-Manufacturer sütunuda bulunan ilk satırdaki arabanın değerini none yapın ve daha sonra eksik değer varmı yok mu konrol edin?**

# %%
veri["Manufacturer"][0]=None
veri.Manufacturer.isnull().head()
# Out:
# <ipython-input-20-2ddd2a6e0bd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   veri["Manufacturer"][0]=None
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Manufacturer, dtype: bool

# %% [markdown]
# **6-Her bir sütunda ne kadar eksik değer var görüntüleyin?**

# %%
veri.isnull().sum()
# Out:
# Manufacturer           1
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %% [markdown]
# ## Eksik Verileri Filtreleme

# %% [markdown]
# **7-Manufacturer sütununa ait None değerleri .... ile eksik  filtreleyin?**

# %%
veri.Manufacturer.dropna().head()
# Out:
# 1    Acura
# 2    Acura
# 3    Acura
# 4    Audi
# 5    Audi
# Name: Manufacturer, dtype: object

# %% [markdown]
# **8-Verinin satır ve sütun olarak ikinci indeksine kadar olan bölümü None yapın ve filtreleyin ?**

# %% [markdown]
# #veri.iloc[...] = None

# %%
veri.iloc[:2,:2]=None
veri.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0           None               None              16.919               16.36
# 1           None               None              39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %% [markdown]
# #veri....head()

# %% [markdown]
# ## Eksik Verilerin Doldurulması

# %% [markdown]
# **9-Veri frameinde bulunan none değerlere 0 atayın**

# %% [markdown]
# #veri.....head()

# %%
veri.fillna(0).head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0              0                  0              16.919               16.36
# 1              0                  0              39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %% [markdown]
# **10-Model sütunun ilk 4 satırına none değerlerini atayın?**

# %%
veri.iloc[:4,1]=None
veri.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0           None               None              16.919               16.36
# 1           None               None              39.384              19.875
# 2  Acura                       None              14.114              18.225
# 3  Acura                       None               8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %% [markdown]
# **11-Daha sonra Modeliçin none değerleri 12 , Sales in thousands için 15 olarak doldurun?**

# %% [markdown]
# #veri....({"Model":...,"Sales in thousands":...}).head()

# %%
veri.fillna({"Model":12,"Sales in thousands":15})
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0             None                 12              16.919               16.36
# 1             None                 12              39.384              19.875
# 2    Acura                         12              14.114              18.225
# 3    Acura                         12               8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %% [markdown]
# **12-Verisetinde tekrarlayan verilerin var olup olmadığını bulun varsa siliniz?**

# %%
veri.duplicated().sum()
# Out:
# 0

# %%
veri.drop_duplicates()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0             None               None              16.919               16.36
# 1             None               None              39.384              19.875
# 2    Acura                       None              14.114              18.225
# 3    Acura                       None               8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %% [markdown]
# ## YER Değiştirme

# %% [markdown]
# **13-Dataframe de 14.114 görülen yerler 50000 ile değiştirilsin?**

# %%
veri.head()

# %% [markdown]
# #veri....(14.114,50000,).head()

# %%
veri.replace(14.114,50000).head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0           None               None              16.919               16.36
# 1           None               None              39.384              19.875
# 2  Acura                       None           50000.000              18.225
# 3  Acura                       None               8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %% [markdown]
# # Eksen Dizinlerini Yeniden Adlandırma

# %% [markdown]
# **14 sütun isimlerini büyük harfle yazın**

# %% [markdown]
# #veri.rename(...)

# %%
veri.rename(columns=str.upper,inplace=True)

# %% [markdown]
# # VERİ Manipülasyonu

# %% [markdown]
# **15-herhangi bir verisi none olan satırları silin ve dataframi yeniveri adında bir değişkene atayın**

# %%
yeniveri=veri.dropna(how="any",axis=0)
yeniveri.head()
# Out:
#     MANUFACTURER              MODEL  SALES IN THOUSANDS 4-YEAR RESALE VALUE  \
# 4  Audi           A4                             20.397              22.255
# 5  Audi           A6                             18.780              23.555
# 6  Audi           A8                              1.380                  39
# 7  BMW            323i                           19.747                   .
# 8  BMW            328i                            9.231              28.675
#
#   VEHICLE TYPE PRICE IN THOUSANDS ENGINE SIZE HORSEPOWER WHEELBASE WIDTH  \
# 4    Passenger              23.99         1.8        150     102.6  68.2
# 5    Passenger              33.95         2.8        200     108.7  76.1
# 6    Passenger                 62         4.2        310       113    74
# 7    Passenger              26.99         2.5        170     107.3  68.4
# 8    Passenger               33.4         2.8        193     107.3  68.5
#
#   LENGTH CURB WEIGHT FUEL CAPACITY FUEL EFFICIENCY LATEST LAUNCH
# ...

# %% [markdown]
# **16-WHEELBASE, VEHICLE TYPE, CURB WEIGHT,LATEST LAUNCH,4-YEAR RESALE VALUE**   sütunlarını silin

# %%
yeniveri.drop(["WHEELBASE", "VEHICLE TYPE", "CURB WEIGHT","LATEST LAUNCH","4-YEAR RESALE VALUE"],axis=1)
# Out:
#       MANUFACTURER              MODEL  SALES IN THOUSANDS PRICE IN THOUSANDS  \
# 4    Audi           A4                             20.397              23.99
# 5    Audi           A6                             18.780              33.95
# 6    Audi           A8                              1.380                 62
# 7    BMW            323i                           19.747              26.99
# 8    BMW            328i                            9.231               33.4
# ..             ...                ...                 ...                ...
# 152  Volvo          V40                             3.545               24.4
# 153  Volvo          S70                            15.245               27.5
# 154  Volvo          V70                            17.531               28.8
# 155  Volvo          C70                             3.493               45.5
# 156  Volvo          S80                            18.969                 36
#
# ...

# %% [markdown]
# **17-MANUFACTURER sütununda kaç çeşit araba vardır ve bu arabaları listeleyin?**

# %%
yeniveri.MANUFACTURER.value_counts()
# Out:
# Dodge            11
# Ford             11
# Chevrolet         9
# Toyota            9
# Mercedes-Benz     9
# Nissan            7
# Mitsubishi        7
# Chrysler          7
# Volvo             6
# Oldsmobile        6
# Pontiac           6
# Mercury           6
# Lexus             6
# Volkswagen        6
# Honda             5
# Saturn            5
# Cadillac          5
# Buick             4
# Plymouth          4
# Lincoln           3
# Hyundai           3
# Jeep              3
# BMW               3
# Audi              3
# Porsche           3
# Saab              2
# Subaru            2
# Infiniti          1
# Jaguar            1
# Name: MANUFACTURER, dtype: int64

# %%
yeniveri.MANUFACTURER.unique()
# Out:
# array(['Audi         ', 'BMW          ', 'Buick        ', 'Cadillac     ',
#        'Chevrolet    ', 'Chrysler     ', 'Dodge        ', 'Ford         ',
#        'Honda        ', 'Hyundai      ', 'Infiniti     ', 'Jaguar       ',
#        'Jeep         ', 'Lexus        ', 'Lincoln      ', 'Mitsubishi   ',
#        'Mercury      ', 'Mercedes-Benz', 'Nissan       ', 'Oldsmobile   ',
#        'Plymouth     ', 'Pontiac      ', 'Porsche      ', 'Saab         ',
#        'Saturn       ', 'Subaru       ', 'Toyota       ', 'Volkswagen   ',
#        'Volvo        '], dtype=object)

# %% [markdown]
# **18-MANUFACTURER sütununda bulunan değerlerin boşlukları temizleyin aşağıdaki 3. noktayı doldurun**

# %% [markdown]
# #yeniveri["MANUFACTURER"]=yeniveri["MANUFACTURER"].str....

# %%
yeniveri["MANUFACTURER"]=yeniveri["MANUFACTURER"].str.strip()
# Out:
# <ipython-input-72-211fea283409>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yeniveri["MANUFACTURER"]=yeniveri["MANUFACTURER"].str.strip()

# %% [markdown]
# **19-Sadece BMW olanları listeleyin**

# %%
yeniveri[yeniveri["MANUFACTURER"]=="BMW"]
# Out:
#   MANUFACTURER              MODEL  SALES IN THOUSANDS 4-YEAR RESALE VALUE  \
# 7          BMW  323i                           19.747                   .
# 8          BMW  328i                            9.231              28.675
# 9          BMW  528i                           17.527              36.125
#
#   VEHICLE TYPE PRICE IN THOUSANDS ENGINE SIZE HORSEPOWER WHEELBASE WIDTH  \
# 7    Passenger              26.99         2.5        170     107.3  68.4
# 8    Passenger               33.4         2.8        193     107.3  68.5
# 9    Passenger               38.9         2.8        193     111.4  70.9
#
#   LENGTH CURB WEIGHT FUEL CAPACITY FUEL EFFICIENCY LATEST LAUNCH
# 7    176       3.179          16.6              26     28-Jun-15
# 8    176       3.197          16.6              24     29-Jan-14
# 9    188       3.472          18.5              25      4-Apr-15

# %% [markdown]
# **20- SALES IN THOUSANDS'u 200 üzeri olanları listeleyin**

# %%
yeniveri[yeniveri["SALES IN THOUSANDS"]>200]
# Out:
#     MANUFACTURER              MODEL  SALES IN THOUSANDS 4-YEAR RESALE VALUE  \
# 40         Dodge  Ram Pickup                    227.061               15.06
# 49          Ford  Taurus                        245.815              10.055
# 52          Ford  Explorer                      276.747               16.64
# 55          Ford  Ranger                        220.650                7.85
# 56          Ford  F-Series                      540.561              15.075
# 58         Honda  Accord                        230.902               13.21
# 137       Toyota  Camry                         247.994              13.245
#
#     VEHICLE TYPE PRICE IN THOUSANDS ENGINE SIZE HORSEPOWER WHEELBASE WIDTH  \
# 40           Car              19.46         5.2        230     138.7  79.3
# 49     Passenger             17.885           3        155     108.5    73
# 52           Car              31.93           4        210     111.6  70.2
# ...

# %% [markdown]
# **21-'VEHICLE TYPE' sütununda bulunan verileri  binary sütun olarak atayınız**

# %%
dummies=pd.get_dummies(yeniveri["VEHICLE TYPE"])
dummies
# Out:
#      Car  Passenger
# 4      0          1
# 5      0          1
# 6      0          1
# 7      0          1
# 8      0          1
# ..   ...        ...
# 152    0          1
# 153    0          1
# 154    0          1
# 155    0          1
# 156    0          1
#
# [153 rows x 2 columns]

# %% [markdown]
# **22- SALES IN THOUSANDS sütununda bulunan verileri bins = [18, 25, 35, 60, 100] aralıklarına göre kategorize edin**

# %%
bins = [18, 25, 35, 60, 100]

# %%
yeniveri2=pd.cut(yeniveri["SALES IN THOUSANDS"],bins)
yeniveri2.head()
# Out:
# 4    (18.0, 25.0]
# 5    (18.0, 25.0]
# 6             NaN
# 7    (18.0, 25.0]
# 8             NaN
# Name: SALES IN THOUSANDS, dtype: category
# Categories (4, interval[int64]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]
